# %% [markdown]
# ref: https://www.shiyanlou.com/courses/599/labs/1978/document

# %%
from bs4 import BeautifulSoup
from urlparse import urljoin
import requests
import csv

url = "http://bj.58.com/pinpaigongyu/pn/{page}/?minprice=2000_4000"

#已完成的页数序号，初时为0
page = 0

csv_file = open("rent.csv","wb") 
csv_writer = csv.writer(csv_file, delimiter=',')

while True:
    page += 1
    print "fetch: ", url.format(page=page)
    response = requests.get(url.format(page=page))
    html = BeautifulSoup(response.text)
    house_list = html.select(".list > li")

    # 循环在读不到新的房源时结束
    if not house_list:
        break

    for house in house_list:
        house_title = house.select("h2")[0].string.encode("utf8")
        house_url = urljoin(url, house.select("a")[0]["href"])
        house_info_list = house_title.split()

        # 如果第二列是公寓名则取第一列作为地址
        if "公寓" in house_info_list[1] or "青年社区" in house_info_list[1]:
            house_location = house_info_list[0]
        else:
            house_location = house_info_list[1]

        house_money = house.select(".money")[0].select("b")[0].string.encode("utf8")
        csv_writer.writerow([house_title, house_location, house_money, house_url])

csv_file.close()
# Out:
# fetch:  http://bj.58.com/pinpaigongyu/pn/1/?minprice=2000_4000
# /usr/local/lib/python2.7/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /usr/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# fetch:  http://bj.58.com/pinpaigongyu/pn/2/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/3/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/4/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/5/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/6/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/7/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/8/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/9/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/10/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/11/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/12/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/13/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/14/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/15/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/16/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/17/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/18/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/19/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/20/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/21/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/22/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/23/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/24/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/25/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/26/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/27/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/28/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/29/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/30/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/31/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/32/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/33/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/34/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/35/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/36/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/37/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/38/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/39/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/40/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/41/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/42/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/43/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/44/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/45/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/46/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/47/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/48/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/49/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/50/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/51/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/52/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/53/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/54/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/55/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/56/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/57/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/58/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/59/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/60/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/61/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/62/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/63/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/64/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/65/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/66/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/67/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/68/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/69/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/70/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/71/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/72/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/73/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/74/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/75/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/76/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/77/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/78/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/79/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/80/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/81/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/82/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/83/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/84/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/85/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/86/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/87/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/88/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/89/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/90/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/91/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/92/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/93/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/94/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/95/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/96/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/97/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/98/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/99/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/100/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/101/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/102/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/103/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/104/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/105/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/106/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/107/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/108/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/109/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/110/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/111/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/112/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/113/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/114/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/115/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/116/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/117/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/118/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/119/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/120/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/121/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/122/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/123/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/124/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/125/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/126/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/127/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/128/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/129/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/130/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/131/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/132/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/133/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/134/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/135/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/136/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/137/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/138/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/139/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/140/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/141/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/142/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/143/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/144/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/145/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/146/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/147/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/148/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/149/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/150/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/151/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/152/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/153/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/154/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/155/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/156/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/157/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/158/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/159/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/160/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/161/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/162/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/163/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/164/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/165/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/166/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/167/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/168/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/169/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/170/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/171/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/172/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/173/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/174/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/175/?minprice=2000_4000
# fetch:  http://bj.58.com/pinpaigongyu/pn/176/?minprice=2000_4000
